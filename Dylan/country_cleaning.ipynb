# %% [markdown]
# # Cleaning up other resources
#
# ## finding other important data for each country and year

# %%
import pandas as pd
import time
import os

# %%
# ../Resources/government_stability/
filepath1 = "../Resources/government_stability/e78fa797-1ac1-48e7-9992-e55cb8dbb19d_Data.csv"
filepath2 = "../Resources/government_stability/e78fa797-1ac1-48e7-9992-e55cb8dbb19d_Series - Metadata.csv"
df1 = pd.read_csv(filepath1)
df2 = pd.read_csv(filepath2)

# ../Resources/Possible_factors/
filepath3 = "../Resources/Possible_factors/Disaster_data.csv"
df3 = pd.read_csv(filepath3)

# ../Resources/worldbank/world_data.csv
filepath4 = "../Resources/worldbank/world_data.csv"
df4 = pd.read_csv(filepath4)
# filepath5 = "../Resources/worldbank/world_data_meta.csv"
# df5 = pd.read_csv(filepath5)

# clean_df2222.to_csv('../Resources/DataFrames/athleteEventsAggFinalNaN.csv', index=False, header=True)
final_athlete_df = pd.read_csv("../Resources/DataFrames/athleteEventsAggFinalNaN.csv")
final_athlete_df.head(2)
# Out:
#    Year  NOC  Total Athletes  Medal Count  Average Age (M)  \
# 0  1896  AUS               3          4.0            22.25
# 1  1896  AUT               3          5.0            21.75
#
#    Average Height (M)  Average Weight (M)  Average Age (F)  \
# 0                 NaN                 NaN              NaN
# 1                 NaN                 NaN              NaN
#
#    Average Height (F)  Average Weight (F)
# 0                 NaN                 NaN
# 1                 NaN                 NaN

# %%
print(df1.shape)
df1.head(1)
# Out:
# (1601, 68)
#   Country Name Country Code                      Series Name Series Code  \
# 0  Afghanistan          AFG  Control of Corruption: Estimate      CC.EST
#
#   1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964]  \
# 0            ..            ..            ..            ..            ..
#
#   1965 [YR1965]  ...      2014 [YR2014]      2015 [YR2015]      2016 [YR2016]  \
# 0            ..  ...  -1.36474287509918  -1.35423982143402  -1.54035270214081
#
#        2017 [YR2017]      2018 [YR2018]      2019 [YR2019]      2020 [YR2020]  \
# 0  -1.53190970420837  -1.50288057327271  -1.41949915885925  -1.49369978904724
#
#        2021 [YR2021]      2022 [YR2022] 2023 [YR2023]
# 0  -1.15232741832733  -1.18377649784088            ..
#
# [1 rows x 68 columns]

# %%
print(df2.shape)
df2.head(1)
# Out:
# (1608, 68)
#   Country Name Country Code                      Series Name Series Code  \
# 0  Afghanistan          AFG  Control of Corruption: Estimate      CC.EST
#
#   1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964]  \
# 0            ..            ..            ..            ..            ..
#
#   1965 [YR1965]  ...      2014 [YR2014]      2015 [YR2015]      2016 [YR2016]  \
# 0            ..  ...  -1.36474287509918  -1.35423982143402  -1.54035270214081
#
#        2017 [YR2017]      2018 [YR2018]      2019 [YR2019]      2020 [YR2020]  \
# 0  -1.53190970420837  -1.50288057327271  -1.41949915885925  -1.49369978904724
#
#        2021 [YR2021]      2022 [YR2022] 2023 [YR2023]
# 0  -1.15232741832733  -1.18377649784088            ..
#
# [1 rows x 68 columns]

# %%
print(list(df1['Country Name'].unique()))
print(len(list(df1['Country Name'].unique())))
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands', 'Central African Republic', 'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana
# ...

# %%
print(list(df2['Country Name'].unique()))
print(len(list(df2['Country Name'].unique())))
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands', 'Central African Republic', 'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana
# ...

# %%
# Disaster data 
print(df3.shape)
df3.head(1)
# Out:
# (26664, 46)
#   DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0             Yes    nat-met-sto-tro        Natural    Meteorological
#
#   Disaster Type  Disaster Subtype External IDs Event Name  ISO  ...  \
# 0         Storm  Tropical cyclone          NaN        NaN  USA  ...
#
#   Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# 0                             NaN                                       NaN
#
#   Insured Damage ('000 US$) Insured Damage, Adjusted ('000 US$)  \
# 0                       NaN                                 NaN
#
#   Total Damage ('000 US$) Total Damage, Adjusted ('000 US$)       CPI  \
# 0                 30000.0                         1098720.0  2.730451
#
#   Admin Units  Entry Date  Last Update
# 0         NaN  2004-10-18   2023-10-17
#
# [1 rows x 46 columns]

# %%
# worldbank databank https://databank.worldbank.org/source/world-development-indicators#advancedDownloadOptions
# 266 countries 21 series 64 years
print(df4.shape)
df4.head(20)
# Out:
# (5591, 68)
#    Country Name Country Code  \
# 0   Afghanistan          AFG
# 1   Afghanistan          AFG
# 2   Afghanistan          AFG
# 3   Afghanistan          AFG
# 4   Afghanistan          AFG
# 5   Afghanistan          AFG
# 6   Afghanistan          AFG
# 7   Afghanistan          AFG
# 8   Afghanistan          AFG
# 9   Afghanistan          AFG
# 10  Afghanistan          AFG
# 11  Afghanistan          AFG
# 12  Afghanistan          AFG
# 13  Afghanistan          AFG
# 14  Afghanistan          AFG
# 15  Afghanistan          AFG
# 16  Afghanistan          AFG
# 17  Afghanistan          AFG
# 18  Afghanistan          AFG
# 19  Afghanistan          AFG
#
#                                           Series Name        Series Code  \
# 0                                   Population, total        SP.POP.TOTL
# 1                        Population growth (annual %)        SP.POP.GROW
# 2                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# ...

# %%
df44 = df4.copy()
df44.columns = df44.columns.to_series().replace(
    r'^(\d{4}) \[YR\d{4}\]$',
    r'\1',
    regex=True
)
print(df44.columns)
df44.head(2)
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code', '1960',
#        '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')
#   Country Name Country Code                   Series Name  Series Code  \
# 0  Afghanistan          AFG             Population, total  SP.POP.TOTL
# 1  Afghanistan          AFG  Population growth (annual %)  SP.POP.GROW
#
#       1960              1961              1962              1963  \
# ...

# %%
# to do

# %%
df444= df44.sort_values(by=["Series Name", "Country Name"])
df444 = df444.dropna()
print(df444.shape)
df444.head(3)
# Out:
# (5586, 68)
#                      Country Name Country Code  \
# 6                     Afghanistan          AFG
# 4563  Africa Eastern and Southern          AFE
# 4584   Africa Western and Central          AFW
#
#                                           Series Name        Series Code 1960  \
# 6     Armed forces personnel (% of total labor force)  MS.MIL.TOTL.TF.ZS   ..
# 4563  Armed forces personnel (% of total labor force)  MS.MIL.TOTL.TF.ZS   ..
# 4584  Armed forces personnel (% of total labor force)  MS.MIL.TOTL.TF.ZS   ..
#
#      1961 1962 1963 1964 1965  ...               2014               2015  \
# 6      ..   ..   ..   ..   ..  ...   3.72705501582188   3.70073240669033
# 4563   ..   ..   ..   ..   ..  ...   0.62903026918525  0.605281900453963
# 4584   ..   ..   ..   ..   ..  ...  0.301808284295757   0.32145256580984
#
#                    2016               2017               2018  \
# 6      3.62353877713756   3.49015888651181    2.9525937221301
# ...

# %%
country_list_df4 = list(df444['Country Name'].unique())
print(country_list_df4)
print(len(country_list_df4))
# Out:
# ['Afghanistan', 'Africa Eastern and Southern', 'Africa Western and Central', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands', 'Central African Republic', 'Central Europe and the Baltics', 'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Early-demographic dividend', 'East Asia & Pacific', 'East Asia & Pacific (IDA & IBRD countries)
# ...

# %%
# saving whole dataframe

df444.to_csv('../Resources/DataFrames/world_data_cleaned.csv', index=False, header=True)
# df444 = pd.read_csv("../Resources/DataFrames/world_data_cleaned.csv")
# df444.head(2)

# %%
increment = 0
series_dfs = {}
for series_name in df444['Series Name'].unique():
    increment += 1
    name = f"series{increment}"
    series_dfs[name] = df444[df444['Series Name'] == series_name]
    print(f" series {name} below ********************")
    print()
    print(series_dfs[name].head(2))
    print()
    series_dfs[name].to_csv(f'../Resources/DataFrames/series_df/{name}.csv', index=False, header=True)
# Out:
#  series series1 below ********************
#
#                      Country Name Country Code  \
# 6                     Afghanistan          AFG
# 4563  Africa Eastern and Southern          AFE
#
#                                           Series Name        Series Code 1960  \
# 6     Armed forces personnel (% of total labor force)  MS.MIL.TOTL.TF.ZS   ..
# 4563  Armed forces personnel (% of total labor force)  MS.MIL.TOTL.TF.ZS   ..
#
#      1961 1962 1963 1964 1965  ...              2014               2015  \
# 6      ..   ..   ..   ..   ..  ...  3.72705501582188   3.70073240669033
# 4563   ..   ..   ..   ..   ..  ...  0.62903026918525  0.605281900453963
#
#                    2016               2017              2018  \
# 6      3.62353877713756   3.49015888651181   2.9525937221301
# 4563  0.538655325908266  0.514660592658541  0.51173656360947
#
#                    2019               2020 2021 2022 2023
# 6      3.01507875591777   1.81204522469526   ..   ..   ..
# ...

# %%
filepath_load = '../Resources/DataFrames/series_df/'
series_df = {}
increment = 0

for file in os.listdir(filepath_load):
    increment +=1
    current_filepath = os.path.join(filepath_load, file)
    series_df[f"series{increment}"] = pd.read_csv(current_filepath)
    name = f"series{increment}"
    print(f"DataFrame series{increment} has been loaded from {file} @ {current_filepath}")
    print()
    print(series_df[name].head(1))
    print()
    print()
# Out:
# DataFrame series1 has been loaded from series3.csv @ ../Resources/DataFrames/series_df/series3.csv
#
#   Country Name Country Code                             Series Name  \
# 0  Afghanistan          AFG  Control of Corruption: Percentile Rank
#
#   Series Code 1960 1961 1962 1963 1964 1965  ...              2014  \
# 0  CC.PER.RNK   ..   ..   ..   ..   ..   ..  ...  5.28846168518066
#
#               2015              2016              2017             2018  \
# 0  5.7142858505249  3.80952382087708  3.80952382087708  4.7619047164917
#
#               2019             2020             2021              2022 2023
# 0  5.7142858505249  4.7619047164917  12.380952835083  12.2641506195068   ..
#
# [1 rows x 68 columns]
#
#
# DataFrame series2 has been loaded from series2.csv @ ../Resources/DataFrames/series_df/series2.csv
#
#   Country Name Country Code                             Series Name  \
# 0  Afghanistan          AFG  Compulsory education, duration (years)
#
# ...

# %%
# before saving
# series_dfs['series8']
# after saving
series_df['series20']
# Out:
#                     Country Name Country Code                   Series Name  \
# 0                    Afghanistan          AFG  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2     Africa Western and Central          AFW  GDP per capita (current US$)
# 3                        Albania          ALB  GDP per capita (current US$)
# 4                        Algeria          DZA  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 261           West Bank and Gaza          PSE  GDP per capita (current US$)
# 262                        World          WLD  GDP per capita (current US$)
# 263                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 264                       Zambia          ZMB  GDP per capita (current US$)
# 265                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...
