# %%
import pandas as pd
import numpy as np

# %%
test_df = pd.read_csv("../Resources/overall_stability/72ef81b1-ee7d-48ce-b7de-0140a458a4c1_Data.csv")

test_df = test_df.dropna()

# test_df.set_index('Country Name', inplace=True)

# test_df= test_df.drop('Data from database: Environment Social and Governance (ESG) Data')
# test_df = test_df.drop("Last Updated: 04/16/2024")

test_df
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 3580        World          WLD
# 3581        World          WLD
# 3582        World          WLD
# 3583        World          WLD
# 3584        World          WLD
#
#                                             Series Name        Series Code  \
# 0               Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1     Cause of death, by communicable diseases and m...     SH.DTH.COMM.ZS
# 2                       Control of Corruption: Estimate             CC.EST
# 3          Economic and Social Rights Performance Score     SD.ESR.PERF.XQ
# 4                                 GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# ...                                                 ...                ...
# ...

# %%
sort = test_df.sort_values(by=["Series Name", "Country Name"])
sort
# pivot_df = test_df.pivot_table(index='year', columns=['1960 [YR1960]', '1961 [YR1961]', '1962 [YR1962]', '1963 [YR1963]', '1964 [YR1964]', '1965 [YR1965]', '1966 [YR1966]'], values='values').reset_index()
# pivot_df
# Out:
#      Country Name Country Code                              Series Name  \
# 0     Afghanistan          AFG  Access to electricity (% of population)
# 15        Albania          ALB  Access to electricity (% of population)
# 30        Algeria          DZA  Access to electricity (% of population)
# 45        Andorra          AND  Access to electricity (% of population)
# 60         Angola          AGO  Access to electricity (% of population)
# ...           ...          ...                                      ...
# 2849     Viet Nam          VNM       Voice and Accountability: Estimate
# 3584        World          WLD       Voice and Accountability: Estimate
# 2864  Yemen, Rep.          YEM       Voice and Accountability: Estimate
# 2879       Zambia          ZMB       Voice and Accountability: Estimate
# 2894     Zimbabwe          ZWE       Voice and Accountability: Estimate
#
#          Series Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# ...

# %%
cat_df = sort[sort['Series Name'] == "Access to electricity (% of population)"]
cat_df
# Out:
#      Country Name Country Code                              Series Name  \
# 0     Afghanistan          AFG  Access to electricity (% of population)
# 15        Albania          ALB  Access to electricity (% of population)
# 30        Algeria          DZA  Access to electricity (% of population)
# 45        Andorra          AND  Access to electricity (% of population)
# 60         Angola          AGO  Access to electricity (% of population)
# ...           ...          ...                                      ...
# 2835     Viet Nam          VNM  Access to electricity (% of population)
# 3570        World          WLD  Access to electricity (% of population)
# 2850  Yemen, Rep.          YEM  Access to electricity (% of population)
# 2865       Zambia          ZMB  Access to electricity (% of population)
# 2880     Zimbabwe          ZWE  Access to electricity (% of population)
#
#          Series Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# ...

# %%
# Transpose the DataFrame
df_transposed = test_df.transpose()
# df_transposed

# # Make the first row the column names
df_transposed.columns = df_transposed.iloc[0]   # Set the first row as the header
df_transposed = df_transposed[1:]               # Remove the first row from the DataFrame
df_transposed.reset_index(drop=True, inplace=False)  # Reset the index

df_transposed
# df_transposed.to_csv('Transposed_data_1.csv', index=False)
# Out:
# Country Name                               Afghanistan  \
# Country Code                                       AFG
# Series Name    Access to electricity (% of population)
# Series Code                             EG.ELC.ACCS.ZS
# 1960 [YR1960]                                       ..
# 1961 [YR1961]                                       ..
# ...                                                ...
# 2019 [YR2019]                                     97.7
# 2020 [YR2020]                                     97.7
# 2021 [YR2021]                                     97.7
# 2022 [YR2022]                                       ..
# 2023 [YR2023]                                       ..
#
# Country Name                                         Afghanistan  \
# Country Code                                                 AFG
# Series Name    Cause of death, by communicable diseases and m...
# Series Code                                       SH.DTH.COMM.ZS
# ...

# %%
overall_stability_df = pd.read_csv("../Resources/overall_stability/Overall_stability.csv")
overall_stability_df = overall_stability_df.dropna()
overall_stability_df = overall_stability_df[overall_stability_df['g_Values'] != ".."]
overall_stability_df = overall_stability_df.sort_values(["Country Name", "Series Name", "year"])
overall_stability_df
overall_stability_df.to_csv('../Resources/overall_stability/Overall_stability_cleaned.csv', index=False)

# %%
gov_stability_df = pd.read_csv("../Resources/government_stability/Government_stability.csv")
gov_stability_df = gov_stability_df.dropna()
gov_stability_df = gov_stability_df[gov_stability_df['gov_stability_values'] != ".."]
gov_stability_df = gov_stability_df.sort_values(["Country Name", "Series Name", "year"])
gov_stability_df
gov_stability_df.to_csv('../Resources/government_stability/Government_stability_cleaned.csv', index=False)

# %%
csv_files = [
    "../Resources/DataFrames/series_df/series_tableau/series1.csv",
    "../Resources/DataFrames/series_df/series_tableau/series2.csv",
    "../Resources/DataFrames/series_df/series_tableau/series3.csv",
    "../Resources/DataFrames/series_df/series_tableau/series4.csv",
    "../Resources/DataFrames/series_df/series_tableau/series5.csv",
    "../Resources/DataFrames/series_df/series_tableau/series6.csv",
    "../Resources/DataFrames/series_df/series_tableau/series7.csv",
    "../Resources/DataFrames/series_df/series_tableau/series8.csv",
    "../Resources/DataFrames/series_df/series_tableau/series9.csv",
    "../Resources/DataFrames/series_df/series_tableau/series10.csv",
    "../Resources/DataFrames/series_df/series_tableau/series11.csv",
    "../Resources/DataFrames/series_df/series_tableau/series12.csv",
    "../Resources/DataFrames/series_df/series_tableau/series13.csv",
    "../Resources/DataFrames/series_df/series_tableau/series14.csv",
    "../Resources/DataFrames/series_df/series_tableau/series15.csv",
    "../Resources/DataFrames/series_df/series_tableau/series16.csv",
    "../Resources/DataFrames/series_df/series_tableau/series17.csv",
    "../Resources/DataFrames/series_df/series_tableau/series18.csv",
    "../Resources/DataFrames/series_df/series_tableau/series19.csv",
    "../Resources/DataFrames/series_df/series_tableau/series20.csv",
    "../Resources/DataFrames/series_df/series_tableau/series21.csv"
]

cleaned_dfs = {}

for i, file in enumerate(csv_files):

    df = pd.read_csv(file)
    
    df_cleaned = df.dropna()
    df_cleaned = df_cleaned[df_cleaned[f'values_T{i+1}'] != ".."]
    df_cleaned = df_cleaned.sort_values(["Country Name", "Series Name", f'year_T{i+1}'])
    
    cleaned_dfs[f'series_df_{i+1}'] = df_cleaned

    cleaned_dfs[f'series_df_{i+1}'].to_csv(f'../Resources/DataFrames/series_df/series_cleaned/series{i+1}_cleaned.csv', index=False)

# cleaned_dfs[f'series_df_21']

# %%
series1_df = pd.read_csv("../Resources/government_stability/Government_stability.csv")
series1_df = series1_df.dropna()
series1_df = series1_df[series1_df['armed_values'] != ".."]
series1_df = series1_df.sort_values(["Country Name", "Series Name", "year"])
series1_df
series1_df.to_csv('../Resources/government_stability/Government_stability_cleaned.csv', index=False)

# %%
# import findspark
# findspark.init()
# from pyspark.sql import SparkSession
# from pyspark import SparkFiles

# spark = SparkSession.builder.appName("olympian").getOrCreate()

# path = "../Resources/All_olympic_competitors/athleteEvents.csv"

# spark.sparkContext.addFile(path)
# olympic_df = spark.read.csv(SparkFiles.get("athleteEvents.csv"), sep=",", header=True)
# olympic_df.show()
